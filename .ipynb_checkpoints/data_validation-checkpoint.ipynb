# %%
import pandas as pd

# %%
preprocessed_sale_data = pd.read_csv('./data/sale_data_feature_elichen.csv')

# %%
preprocessed_sale_future_data = pd.read_csv('./data/sale_future_data_feature_elichen.csv')

# %%
preprocessed_sale_data.head()
# Out:
#    Unnamed: 0  City_Land_Usage  Parking_Area                   編號  Elevator  \
# 0        3499              1.0             0  RPUNMLQLJHMFFDA08CA         0
# 1        3656              1.0             0  RPPOMLQJKHMFFEA67CA         1
# 2        3718              1.0             0  RPQPMLLKJHMFFDA27CA         0
# 3        3723              4.0            11  RPRQMLKLJHMFFCA37CA         0
# 4        3740              1.0             0  RPQOMLLKJHMFFCA07CA         1
#
#    Main_Usage_Walk  Main_Usage_Living  Main_Usage_Selling  \
# 0                0                  1                   0
# 1                0                  1                   0
# 2                0                  0                   0
# 3                0                  0                   0
# 4                0                  1                   0
#
#    Main_Usage_Manufacturing  Main_Usage_Business  ...  Building_Material_R  \
# 0                         0                    0  ...                    1
# ...

# %%
preprocessed_sale_data.columns
# Out:
# Index(['Unnamed: 0', 'City_Land_Usage', 'Parking_Area', '編號', 'Elevator',
#        'Main_Usage_Walk', 'Main_Usage_Living', 'Main_Usage_Selling',
#        'Main_Usage_Manufacturing', 'Main_Usage_Business', 'Main_Usage_Parking',
#        'Main_Usage_SnE', 'Main_Usage_Farm', 'Building_Material_S',
#        'Building_Material_R', 'Building_Material_C', 'Building_Material_steel',
#        'Building_Material_stone', 'Building_Material_B', 'Building_Material_W',
#        'Building_Material_iron', 'Building_Material_tile',
#        'Building_Material_clay', 'Building_Material_RC_reinforce'],
#       dtype='object')

# %%
preprocessed_sale_future_data.head()
# Out:
#    Unnamed: 0  City_Land_Usage  Parking_Area                   編號  \
# 0        2571              4.0             8  RPPPMLMLLHMFFBF97CB
# 1        2572              4.0             8  RPQPMLMLLHMFFBF08CB
# 2        2573              4.0             8  RPRPMLMLLHMFFBF18CB
# 3        2574              4.0             8  RPSPMLMLLHMFFBF28CB
# 4        2578              4.0             8  RPSRMLMLLHMFFBF48CB
#
#    Main_Usage_Walk  Main_Usage_Living  Main_Usage_Selling  \
# 0                0                  0                   0
# 1                0                  1                   0
# 2                0                  1                   0
# 3                0                  1                   0
# 4                0                  1                   0
#
#    Main_Usage_Manufacturing  Main_Usage_Business  Main_Usage_Parking  ...  \
# 0                         0                    1                   0  ...
# ...

# %%
preprocessed_sale_future_data.columns
# Out:
# Index(['Unnamed: 0', 'City_Land_Usage', 'Parking_Area', '編號',
#        'Main_Usage_Walk', 'Main_Usage_Living', 'Main_Usage_Selling',
#        'Main_Usage_Manufacturing', 'Main_Usage_Business', 'Main_Usage_Parking',
#        'Main_Usage_SnE', 'Main_Usage_Farm', 'Building_Material_S',
#        'Building_Material_R', 'Building_Material_C', 'Building_Material_steel',
#        'Building_Material_stone', 'Building_Material_B', 'Building_Material_W',
#        'Building_Material_iron', 'Building_Material_tile',
#        'Building_Material_clay', 'Building_Material_RC_reinforce'],
#       dtype='object')
